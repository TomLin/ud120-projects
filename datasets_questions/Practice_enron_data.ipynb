# %%
import pickle

# %%
enron_data = pickle.load(open("../final_project/final_project_dataset.pkl", "r"))

# %%
type(enron_data)
# Out:
# dict

# %%
len(enron_data)
# Out:
# 146

# %%
import pandas as pd
import pprint

# %%
pprint.pprint(enron_data)
# Out:
# {'ALLEN PHILLIP K': {'bonus': 4175000,
#                      'deferral_payments': 2869717,
#                      'deferred_income': -3081055,
#                      'director_fees': 'NaN',
#                      'email_address': 'phillip.allen@enron.com',
#                      'exercised_stock_options': 1729541,
#                      'expenses': 13868,
#                      'from_messages': 2195,
#                      'from_poi_to_this_person': 47,
#                      'from_this_person_to_poi': 65,
#                      'loan_advances': 'NaN',
#                      'long_term_incentive': 304805,
#                      'other': 152,
#                      'poi': False,
#                      'restricted_stock': 126027,
#                      'restricted_stock_deferred': -126027,
#                      'salary': 201955,
#                      'shared_receipt_with_poi': 1407,
#                      'to_messages': 2902,
#                      'total_payments': 4484442,
# ...

# %%
test2 = pd.DataFrame.from_dict(enron_data, orient="index")

# %%
test2.shape
# Out:
# (146, 21)

# %%
print test2
# Out:
#                                  salary to_messages deferral_payments  \
# ALLEN PHILLIP K                  201955        2902           2869717
# BADUM JAMES P                       NaN         NaN            178980
# BANNANTINE JAMES M                  477         566               NaN
# BAXTER JOHN C                    267102         NaN           1295738
# BAY FRANKLIN R                   239671         NaN            260455
# BAZELIDES PHILIP J                80818         NaN            684694
# BECK SALLY W                     231330        7315               NaN
# BELDEN TIMOTHY N                 213999        7991           2144013
# BELFER ROBERT                       NaN         NaN           -102500
# BERBERIAN DAVID                  216582         NaN               NaN
# BERGSIEKER RICHARD P             187922         383               NaN
# BHATNAGAR SANJAY                    NaN         523               NaN
# ...

# %%
test2.poi.sum()
# Out:
# 18

# %%
name_list = pd.read_csv("../final_project/poi_names.txt", sep = ")", skiprows=2, header=None)

# %%
name_list.iloc[:,0] = name_list.iloc[:,0].str.replace("(","")

# %%
name_list.shape
# Out:
# (35, 2)

# %%
test2.loc["PRENTICE JAMES",:]
# Out:
# salary                                            NaN
# to_messages                                       NaN
# deferral_payments                              564348
# total_payments                                 564348
# exercised_stock_options                        886231
# bonus                                             NaN
# restricted_stock                               208809
# shared_receipt_with_poi                           NaN
# restricted_stock_deferred                         NaN
# total_stock_value                             1095040
# expenses                                          NaN
# loan_advances                                     NaN
# from_messages                                     NaN
# other                                             NaN
# from_this_person_to_poi                           NaN
# poi                                             False
# director_fees                                     NaN
# ...

# %%
list(test2.index)
test2.loc["COLWELL WESLEY"]
# Out:
# salary                                      288542
# to_messages                                   1758
# deferral_payments                            27610
# total_payments                             1490344
# exercised_stock_options                        NaN
# bonus                                      1200000
# restricted_stock                            698242
# shared_receipt_with_poi                       1132
# restricted_stock_deferred                      NaN
# total_stock_value                           698242
# expenses                                     16514
# loan_advances                                  NaN
# from_messages                                   40
# other                                       101740
# from_this_person_to_poi                         11
# poi                                           True
# director_fees                                  NaN
# deferred_income                            -144062
# ...

# %%
list(test2.index)
# Out:
# Object `str.filter` not found.

# %%
test2.loc[test2.index.str.contains("JEFF")]
# Out:
#                        salary to_messages deferral_payments total_payments  \
# DONAHUE JR JEFFREY M   278601         865               NaN         875760
# MCMAHON JEFFREY        370448        2355               NaN        4099771
# SHANKMAN JEFFREY A     304110        3221               NaN        3038702
# SHERRICK JEFFREY B        NaN         613               NaN            NaN
# SKILLING JEFFREY K    1111258        3627               NaN        8682716
#
#                      exercised_stock_options    bonus restricted_stock  \
# DONAHUE JR JEFFREY M                  765920   800000           315068
# MCMAHON JEFFREY                      1104054  2600000           558801
# SHANKMAN JEFFREY A                   1441898  2000000           630137
# SHERRICK JEFFREY B                   1426469      NaN           405999
# SKILLING JEFFREY K                  19250000  5600000          6843672
#
#                      shared_receipt_with_poi restricted_stock_deferred  \
# ...

# %%
import numpy as np
pd.isnull([1,2,3, np.nan, np.nan]).sum()
# Out:
# 2

# %%
a = test2["total_payments"].astype(str).astype(float).isnull().sum()
b = test2.shape[0]
a = float(a)
print a
print type(a)
b = float(b)
print b
print type(b)
print "{:.2f}".format(a/b)
# Out:
# 21.0
# <type 'float'>
# 146.0
# <type 'float'>
# 0.14

# %%
a = test2.loc[test2.poi == True].shape[0]
test2["total_payments"] = test2["total_payments"].astype(str).astype(float)
test2.dtypes
test2[(test2.poi == True)].shape
# Out:
# (18, 21)

# %%
print test2["total_payments"].isnull().sum()
print test2.shape

print "{:.2f}".format(float(10)/float(28))
# Out:
# 21
# (146, 21)
# 0.36
